# %%
import pandas as pd

# %%
df = pd.read_csv('processed_data.csv')

# %%
df.head()
# Out:
#                                               prompt  \
# 0  Hi, how about a little match of tic tac toe? L...
# 1  no government on this earth will give up its l...
# 2  FIND OUT WHOSE DEPARTMENT HAS NOT EMPLOYEES. U...
# 3  Place a cup mixed with water and oil. What hap...
# 4                         Give me a funny wifi names
#
#                                           response_a  \
# 0  Sure, I'd be happy to play a game of tic tac t...
# 1  I understand your point, but I would like to c...
# 2  Here is the SQL query with subqueries to find ...
# 3  If you add fire to a cup of water and oil, the...
# 4  1.   \"Wifi-Fly\"\n2.   \"Wifi-Mood\"\n3.   \"...
#
#                                           response_b  winner_model_b  target  \
# 0  Sure, I'd love to play a game of tic tac toe w...               0       0
# 1  That is true. But governments can sometimes cr...               0       0
# 2  To find out whose department has no employees,...               0       0
# ...
